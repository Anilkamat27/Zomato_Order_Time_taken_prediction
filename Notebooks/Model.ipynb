# %%
import pandas as pd
import numpy as np

# %%
dfc = pd.read_csv('/config/workspace/Data/Model_train_data.csv')
df = dfc.copy()

# %%
df
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                     36.0                      4.2            30.327968
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 0                 78.046106                   30.397968
# 1                 76.307589                   10.043064
# 2                 73.916619                   18.652450
# 3                 75.809346                   30.919584
# 4                 80.372929                   26.593504
# ...                     ...                         ...
# 45579             75.794257                   26.912328
# 45580              0.000000                    0.070000
# 45581             80.242439                   13.052394
# 45582             76.986241                   11.041753
# 45583             85.325731                   23.431058
#
#        Delivery_location_longitude   Distance Weather_conditions  \
# 0                        78.116106  10.280582                Fog
# 1                        76.347589   6.242319             Stormy
# 2                        74.006619  13.787860         Sandstorms
# 3                        75.829346   2.930258         Sandstorms
# 4                        80.502929  19.396618                Fog
# ...                            ...        ...                ...
# 45579                    75.804257   1.489846              Windy
# 45580                     0.070000  11.007735              Windy
# 45581                    80.272439   4.657195             Cloudy
# 45582                    77.026241   6.232393             Cloudy
# 45583                    85.405731  12.074396                Fog
#
#       Road_traffic_density  Vehicle_condition  ...           City  \
# 0                      Jam                  2  ...  Metropolitian
# 1                     High                  1  ...  Metropolitian
# 2                   Medium                  1  ...  Metropolitian
# 3                      Low                  0  ...  Metropolitian
# 4                      Jam                  1  ...  Metropolitian
# ...                    ...                ...  ...            ...
# 45579                 High                  1  ...  Metropolitian
# 45580                  Jam                  0  ...  Metropolitian
# 45581                  Low                  1  ...  Metropolitian
# 45582                 High                  0  ...  Metropolitian
# 45583               Medium                  2  ...  Metropolitian
#
#        Order_prepare_time Order_Day Order_Month  Order_Year  Order_Hour  \
# 0                    15.0        12           2        2022        21.0
# 1                    10.0        13           2        2022        14.0
# 2                    10.0         4           3        2022        17.0
# 3                    10.0        13           2        2022         9.0
# 4                    15.0        14           2        2022        19.0
# ...                   ...       ...         ...         ...         ...
# 45579                10.0        24           3        2022        11.0
# 45580                15.0        16           2        2022        19.0
# 45581                15.0        11           3        2022        23.0
# 45582                 5.0         7           3        2022        13.0
# 45583                 5.0         2           3        2022        17.0
#
#        Order_Min  Picked_Hour  Picked_Min  Time_taken
# 0           55.0         22.0        10.0          46
# 1           55.0         15.0         5.0          23
# 2           30.0         17.0        40.0          21
# 3           20.0          9.0        30.0          20
# 4           50.0         20.0         5.0          41
# ...          ...          ...         ...         ...
# 45579       35.0         11.0        45.0          32
# 45580       55.0         20.0        10.0          36
# 45581       50.0         24.0         5.0          16
# 45582       35.0         13.0        40.0          26
# 45583       10.0         17.0        15.0          36
#
# [45584 rows x 23 columns]

# %%
X=df.drop(labels=['Time_taken'],axis=1)
Y=df[['Time_taken']]

# %%
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
categorical_cols
# Out:
# Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_vehicle',
#        'Festival', 'City'],
#       dtype='object')

# %%
Weather_conditions_Map=["Sunny","Stormy","Sandstorms","Windy","Fog","Cloudy"]
Road_Traffic_Map=["Low","Medium","High","Jam"]
Type_of_vehicle_map=["bicycle","electric_scooter","scooter","motorcycle"]
Festival_Map=["No","Yes"]
City_Map=["Urban","Metropolitian","Semi-Urban"]

# %%
from sklearn.impute import SimpleImputer ##Handling Missing Values
from sklearn.preprocessing import StandardScaler ##Handling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder ##Handling categorical data doing Ordinal Encoding
from sklearn.pipeline import Pipeline ## To create a pipeline so things happen in sequence
from sklearn.compose import ColumnTransformer ## To combine num and cat pipelines

# %%
##Numerical Pipelines

num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
    ]
)

##Categorical Pipelinr

cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OrdinalEncoder(categories=[Weather_conditions_Map,Road_Traffic_Map,Type_of_vehicle_map,Festival_Map,City_Map])),
    ('scaler',StandardScaler())
    ]
)

preprocessor=ColumnTransformer( [
    ('num_pipeline',num_pipeline,numerical_cols),
    ('cat_pipeline',cat_pipeline,categorical_cols)
])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
X_train
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 5755                  36.0                      4.1            22.310329
# 9163                  29.0                      3.6            22.310526
# 16410                 31.0                      4.8            26.473698
# 36945                 33.0                      4.2            15.157944
# 14679                 34.0                      4.1            19.126630
# ...                    ...                      ...                  ...
# 919                   37.0                      4.9            26.474986
# 33268                 28.0                      4.9            17.431477
# 44845                 20.0                      NaN            22.514585
# 4517                  34.0                      4.6            12.970324
# 38693                 22.0                      4.7            13.058616
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 5755              73.169083                   22.380329
# 9163              73.170937                   22.370526
# 16410             80.352677                   26.493698
# 36945             73.950889                   15.287944
# 14679             72.829976                   19.146630
# ...                     ...                         ...
# 919               80.342796                   26.494986
# 33268             78.400350                   17.481477
# 44845             88.393310                   22.594585
# 4517              77.645748                   12.990324
# 38693             80.264151                   13.108616
#
#        Delivery_location_longitude   Distance Weather_conditions  \
# 5755                     73.239083  10.602504         Sandstorms
# 9163                     73.230937   9.088005              Sunny
# 16410                    80.372677   2.984613              Windy
# 36945                    74.080889  20.087481              Windy
# 14679                    72.849976   3.059403              Windy
# ...                            ...        ...                ...
# 919                      80.362796   2.984598              Sunny
# 33268                    78.450350   7.683745                Fog
# 44845                    88.473310  12.108727                Fog
# 4517                     77.665748   3.105145             Cloudy
# 38693                    80.314151   7.761285              Windy
#
#       Road_traffic_density  Vehicle_condition  ... Festival           City  \
# 5755                   Jam                  0  ...       No  Metropolitian
# 9163                   Jam                  0  ...      Yes          Urban
# 16410                  Low                  2  ...       No  Metropolitian
# 36945                  Jam                  2  ...       No  Metropolitian
# 14679                  Low                  0  ...       No          Urban
# ...                    ...                ...  ...      ...            ...
# 919                    Low                  1  ...       No          Urban
# 33268               Medium                  2  ...       No  Metropolitian
# 44845                  Low                  2  ...       No  Metropolitian
# 4517                   Low                  1  ...       No  Metropolitian
# 38693                  Jam                  0  ...       No  Metropolitian
#
#       Order_prepare_time Order_Day  Order_Month  Order_Year  Order_Hour  \
# 5755                10.0         2            3        2022        21.0
# 9163                 5.0        19            3        2022        21.0
# 16410               10.0        15            2        2022        10.0
# 36945               15.0        14            2        2022        19.0
# 14679                NaN         9            3        2022         8.0
# ...                  ...       ...          ...         ...         ...
# 919                 10.0        17            2        2022         8.0
# 33268                5.0         1            4        2022        17.0
# 44845                5.0        14            2        2022        22.0
# 4517                15.0         3            4        2022         8.0
# 38693                5.0        13            3        2022        19.0
#
#        Order_Min  Picked_Hour  Picked_Min
# 5755        40.0       21.000        50.0
# 9163        10.0       21.000        15.0
# 16410       45.0       10.000        55.0
# 36945       15.0       19.000        30.0
# 14679       45.0        0.375         NaN
# ...          ...          ...         ...
# 919         25.0        8.000        35.0
# 33268       40.0       17.000        45.0
# 44845       20.0       22.000        25.0
# 4517        55.0        9.000        10.0
# 38693       50.0       19.000        55.0
#
# [31908 rows x 22 columns]

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train) , columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test) , columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#        num_pipeline__Delivery_person_Age  \
# 0                               1.124025
# 1                              -0.106505
# 2                               0.245075
# 3                               0.596655
# 4                               0.772445
# ...                                  ...
# 31903                           1.299815
# 31904                          -0.282295
# 31905                          -1.688616
# 31906                           0.772445
# 31907                          -1.337036
#
#        num_pipeline__Delivery_person_Ratings  \
# 0                                  -1.623440
# 1                                  -3.143059
# 2                                   0.504025
# 3                                  -1.319517
# 4                                  -1.623440
# ...                                      ...
# 31903                               0.807948
# 31904                               0.807948
# 31905                               0.200101
# 31906                              -0.103822
# 31907                               0.200101
#
#        num_pipeline__Restaurant_latitude  num_pipeline__Restaurant_longitude  \
# 0                               0.647373                            0.131167
# 1                               0.647397                            0.131248
# 2                               1.156141                            0.443938
# 3                              -0.226656                            0.165206
# 4                               0.258322                            0.116402
# ...                                  ...                                 ...
# 31903                           1.156298                            0.443508
# 31904                           0.051172                            0.358934
# 31905                           0.672333                            0.794024
# 31906                          -0.493985                            0.326079
# 31907                          -0.483196                            0.440083
#
#        num_pipeline__Delivery_location_latitude  \
# 0                                      0.669961
# 1                                      0.668629
# 2                                      1.228657
# 3                                     -0.293358
# 4                                      0.230746
# ...                                         ...
# 31903                                  1.228832
# 31904                                  0.004577
# 31905                                  0.699062
# 31906                                 -0.605431
# 31907                                 -0.589364
#
#        num_pipeline__Delivery_location_longitude  num_pipeline__Distance  \
# 0                                       0.116679               -0.079476
# 1                                       0.116295               -0.080867
# 2                                       0.452410               -0.086475
# 3                                       0.156297               -0.070761
# 4                                       0.098366               -0.086406
# ...                                          ...                     ...
# 31903                                   0.451945               -0.086475
# 31904                                   0.361939               -0.082157
# 31905                                   0.833653               -0.078092
# 31906                                   0.325013               -0.086364
# 31907                                   0.449655               -0.082086
#
#        num_pipeline__Vehicle_condition  num_pipeline__multiple_deliveries  \
# 0                            -1.223528                          -1.318236
# 1                            -1.223528                           3.943714
# 2                             1.160323                           0.435747
# 3                             1.160323                           0.435747
# 4                            -1.223528                           0.435747
# ...                                ...                                ...
# 31903                        -0.031602                          -1.318236
# 31904                         1.160323                          -1.318236
# 31905                         1.160323                           0.435747
# 31906                        -0.031602                           0.435747
# 31907                        -1.223528                           0.435747
#
#        num_pipeline__Order_prepare_time  ...  num_pipeline__Order_Year  \
# 0                              0.003553  ...                       0.0
# 1                             -1.379135  ...                       0.0
# 2                              0.003553  ...                       0.0
# 3                              1.386242  ...                       0.0
# 4                              0.003553  ...                       0.0
# ...                                 ...  ...                       ...
# 31903                          0.003553  ...                       0.0
# 31904                         -1.379135  ...                       0.0
# 31905                         -1.379135  ...                       0.0
# 31906                          1.386242  ...                       0.0
# 31907                         -1.379135  ...                       0.0
#
#        num_pipeline__Order_Hour  num_pipeline__Order_Min  \
# 0                      0.771107                 0.527442
# 1                      0.771107                -1.710538
# 2                     -0.945003                 0.900438
# 3                      0.459087                -1.337541
# 4                     -1.257023                 0.900438
# ...                         ...                      ...
# 31903                 -1.257023                -0.591548
# 31904                  0.147067                 0.527442
# 31905                  0.927117                -0.964545
# 31906                 -1.257023                 1.646431
# 31907                  0.459087                 1.273435
#
#        num_pipeline__Picked_Hour  num_pipeline__Picked_Min  \
# 0                       0.730584                  1.238589
# 1                       0.730584                 -1.076966
# 2                      -0.959422                  1.569382
# 3                       0.423310                 -0.084585
# 4                      -2.438177                 -0.084585
# ...                          ...                       ...
# 31903                  -1.266696                  0.246208
# 31904                   0.116036                  0.907795
# 31905                   0.884220                 -0.415379
# 31906                  -1.113059                 -1.407759
# 31907                   0.423310                  1.569382
#
#        cat_pipeline__Weather_conditions  cat_pipeline__Road_traffic_density  \
# 0                             -0.316528                            1.308057
# 1                             -1.490785                            1.308057
# 2                              0.270600                           -1.093916
# 3                              0.270600                            1.308057
# 4                              0.270600                           -1.093916
# ...                                 ...                                 ...
# 31903                         -1.490785                           -1.093916
# 31904                          0.857728                           -0.293258
# 31905                          0.857728                           -1.093916
# 31906                          1.444857                           -1.093916
# 31907                          0.270600                            1.308057
#
#        cat_pipeline__Type_of_vehicle  cat_pipeline__Festival  \
# 0                           0.777630               -0.142953
# 1                           0.777630                6.995304
# 2                          -0.753919               -0.142953
# 3                          -0.753919               -0.142953
# 4                           0.777630               -0.142953
# ...                              ...                     ...
# 31903                       0.777630               -0.142953
# 31904                       0.777630               -0.142953
# 31905                      -0.753919               -0.142953
# 31906                       0.777630               -0.142953
# 31907                       0.777630               -0.142953
#
#        cat_pipeline__City
# 0                0.516375
# 1               -1.859815
# 2                0.516375
# 3                0.516375
# 4               -1.859815
# ...                   ...
# 31903           -1.859815
# 31904            0.516375
# 31905            0.516375
# 31906            0.516375
# 31907            0.516375
#
# [31908 rows x 22 columns]

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
def evaluated_model(true,predicted):
    mae = mean_absolute_error(true,predicted)
    mse = mean_squared_error(true,predicted)
    rmse = np.sqrt(mean_squared_error(true,predicted))
    r2_square = r2_score(true,predicted)
    return mae,rmse,r2_square

# %%
#Train multiple models
models ={
    'LinearRegression' : LinearRegression(),
    'Lasso' : Lasso(),
    'Ridge' : Ridge(),
    'ElasticNet': ElasticNet()
}

# %%
model_list = []
r2_list = []

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    #make predictions
    y_pred = model.predict(X_test)

    mae ,rmse , r2_square = evaluated_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training performance')
    print("RMSE:",rmse)
    print("MAE",mae)
    print("R2 Score",r2_square*100)

    r2_list.append(r2_square)

    print('='*35)
# Out:
# LinearRegression
# Model Training performance
# RMSE: 6.430916416905089
# MAE 5.107213327830114
# R2 Score 52.18599208175171
# ===================================
# Lasso
# Model Training performance
# RMSE: 6.8586110494624215
# MAE 5.4754587999888695
# R2 Score 45.614669936212294
# ===================================
# Ridge
# Model Training performance
# RMSE: 6.4309144278646135
# MAE 5.107211576195977
# R2 Score 52.1860216588683
# ===================================
# ElasticNet
# Model Training performance
# RMSE: 6.941535614421852
# MAE 5.561218587509366
# R2 Score 44.291619736197816
# ===================================
